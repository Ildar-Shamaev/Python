# %% [markdown]
# ### Библиотека requests

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %%
#Код ответа в виде числовой переменной можно получить с помощью метода status_code:

print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %%
print(response.text[:750]) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2024-11-20T11:30:00+03:00",
#     "PreviousDate": "2024-11-19T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2024\/11\/19\/daily_json.js",
#     "Timestamp": "2024-11-19T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 65.1026,
#             "Previous": 64.6831
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 58.844,
#             "Previous": 58.79
#         },
#         "GBP":

# %% [markdown]
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь. В объект ответа Response  из библиотеки requests уже встроен метод json() .

# %%
from pprint import pprint # Импортируем функцию pprint()
import json # Импортируем модуль json
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2024-11-20T11:30:00+03:00',
#  'PreviousDate': '2024-11-19T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2024/11/19/daily_json.js',
#  'Timestamp': '2024-11-19T20:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 27.2139,
#                     'Value': 27.2389},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 25.6996,
#                     'Value': 25.7179},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 64.6831,
#                     'Value': 65.1026},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 58.79,
#                     'Value': 58.844},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 54.0791,
#                     'Value': 53.9702},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 17.2667,
#                     'Value': 17.3672},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 29.4843,
#                     'Value': 29.4775},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 70.9873,
#                     'Value': 71.2397},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 112.8152,
#                     'Value': 113.2},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 13.7597,
#                     'Value': 13.7744},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 41.8329,
#                     'Value': 41.7333},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 14.1801,
#                     'Value': 14.1514},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 20.2407,
#                     'Value': 20.1951},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 105.4606,
#                     'Value': 105.7338},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 126.218,
#                     'Value': 126.444},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Грузинский лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 36.5944,
#                     'Value': 36.6253},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 12.8627,
#                     'Value': 12.8761},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 25.7831,
#                     'Value': 25.9218},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Индонезийских рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 62.9047,
#                     'Value': 63.1214},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 11.8433,
#                     'Value': 11.852},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 64.7719,
#                     'Value': 64.781},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 10,
#                     'NumCode': '417',
#                     'Previous': 11.5541,
#                     'Value': 11.5647},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 71.2454,
#                     'Value': 71.8331},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 20.1518,
#                     'Value': 20.0917},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 55.1842,
#                     'Value': 55.146},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 90.4093,
#                     'Value': 90.0882},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 58.7065,
#                     'Value': 58.8305},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 24.3781,
#                     'Value': 24.3678},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 27.4569,
#                     'Value': 27.4821},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 21.1851,
#                     'Value': 21.2343},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 90.0275,
#                     'Value': 90.5279},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 91.2555,
#                     'Value': 90.9971},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 74.4122,
#                     'Value': 74.77},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Таиландских батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 28.7449,
#                     'Value': 28.9026},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 93.727,
#                     'Value': 93.829},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 28.5551,
#                     'Value': 28.5814},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 29.0835,
#                     'Value': 29.0266},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 24.2112,
#                     'Value': 24.1796},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 99.943,
#                     'Value': 100.0348},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 78.0055,
#                     'Value': 77.9998},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Вьетнамских донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 41.1491,
#                     'Value': 41.1784},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 131.3841,
#                     'Value': 131.3047},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 55.1218,
#                     'Value': 55.6881}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 105.4606,
#  'Value': 105.7338}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ### Получаем содержимое веб-страницы

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text[:1000])  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" as="font" type="font/woff2" crossorigin />
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" as="font" type="font/woff2" crossorigin />
#   <link href="/front-build/css/main.css?id=842e64708435127ee441c2e86afffea2" rel="stylesheet">
#   <link href="/front-build/css/app.css?id=92673ebe7185ebc42e29fc7294a4c65f" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="

# %% [markdown]
# ### Библиотека BeautifulSoup

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Если при запросе к сайту, а затем при его разборе с помощью BeautifulSoup в тексте страницы не находится нужный тег, попробуйте вывести на печать пару тысяч символов текста страницы. Если там обнаружится нечто похожее на капчу, возможно, сайт посчитал вас роботом и отказывается выдавать содержимое. Чтобы получить его, попробуйте «притвориться» браузером при запросе из скрипта:
#
# ```requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}) ```
# User-Agent своего браузера можно узнать по этой ссылке.

# %%
# Применяем метод find() к объекту и выводим результат на экран
print(page.find('h1').text)
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ### Задание
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок первого уровня для статей на Wikipedia.
#
# Функция wiki_header принимает один аргумент - url.

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

def wiki_header(url):
    response = requests.get(url)
    page = BeautifulSoup(response.text, 'html.parser')
    return (page.find('h1').text) 
    

print(wiki_header('https://en.wikipedia.org/wiki/Operating_system'))
# Out:
# Operating system

# %% [markdown]
# ### Неуникальные теги: извлекаем текст и дату публикации статьи

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div (Ничего не вывелось)

# %%
print(page.find('div', class_='n1_material text-18').text) # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
# Выводим на экран содержимое атрибута text тега a с классом "relative"
print(page.find('a', class_= "relative").text)
# Out:
# 11.10.21

# %% [markdown]
# ### Сбор нескольких элементов: собираем все ссылки на странице

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %% [markdown]
# Мы получили только одну ссылку, хотя на странице их явно больше.
#
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 949

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['MAD/I', 'Magik', 'Magma', 'Maple', 'MAPPER', 'MARK-IV', 'Mary', 'MATLAB', 'MASM Microsoft Assembly x86', 'MATH-MATIC']

# %% [markdown]
# # Работа с API

# %%
import requests # Импортируем модуль requests
#token = '' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# ### Задание
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.

# %%
import requests
#token = ''
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.49

# %% [markdown]
# ### Сбор информации из групп

# %%
import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13698000, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 997, 1000, 1018, 1023, 1032, 1033, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1273, 1301, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2909, 2919, 2922, 2932, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 3994, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4790, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5073, 5161, 5166, 5183, 5251, 5262, 5273, 5276, 5280, 5286, 5354, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5484, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5968, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6240, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6440, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6960, 6994, 7012, 7040, 7047, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7126, 7141, 7188, 7200, 7226, 7227, 7286, 7290, 7338, 7360, 7402, 7404, 7408, 7428, 7451, 7481, 7488, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8069, 8080, 8093, 8149, 8151, 8156, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8485, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9018, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9343, 9352, 9399, 9408, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9598, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9925, 9954, 9971, 9981, 9993, 10090, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 11986, 12005, 12029, 12036, 12097, 12133, 12150, 12154, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12597, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 127 ...

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 13 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %%
import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %%
#Сравним списки, полученные двумя способами:
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# ### Ограничение по частоте запросов

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ### Лайки, репосты и комментарии

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 774,
#               'items': [{'attachments': [{'photo': {'access_key': 'c63f20a62cafbe0d28',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354304,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'd5949a55bce1800b31'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '6a9bd0496456580f64',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354305,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'bc07575040c6ce65c7'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': 'b8529cc9a2bd86655a',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354306,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '10c4de8e50fca74f07'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 488},
#                          'date': 1732002300,
#                          'from_id': -22822305,
#                          'hash': 'bVCss2zuaafY0yg5jQ',
#                          'id': 1526639,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 222,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 44},
#                          'text': 'Мы изучили портрет пользователя донатных '
#                                  'сервисов и узнали много интересного.\n'
#                                  '\n'
#                                  'Оказалось, что молодёжь чаще поддерживает '
#                                  'художников и иллюстраторов, а люди старше 25 '
#                                  'лет больше донатят за образовательный '
#                                  'контент.\n'
#                                  '\n'
#                                  'Что мотивирует людей донатить? У мужчин на '
#                                  'первом месте желание поддержать автора, а '
#                                  'женщины больше ценят доступ к эксклюзивным '
#                                  'материалам.\n'
#                                  '\n'
#                                  'Листайте карточки, там ещё больше интересных '
#                                  'фактов! А поддержать своих любимых авторов '
#                                  'вы можете через [vk.com/vkdonut|VK Donut].',
#                          'type': 'post',
#                          'views': {'count': 110475}},
#                         {'attachments': [{'photo': {'access_key': '741d2be37a5b6a16f1',
#                                                     'album_id': -7,
#                                                     'date': 1731410798,
#                                                     'id': 457354071,
#                                                     'orig_photo': {'height': 2160,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu',
#                                                                    'width': 2160},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1524596,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=2160x2160',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'c5868cce0cb6fba08f'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 1464},
#                          'date': 1731411000,
#                          'from_id': -22822305,
#                          'hash': 'FC7YyHuAwt3EgcuJzw',
#                          'id': 1524596,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 425,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 131},
#                          'text': 'В чатах ВКонтакте появилась папка «Бизнес».\n'
#                                  '\n'
#                                  'Статус доставки товара, уведомления о '
#                                  'кешбэке и подтверждения записи в салон '
#                                  'красоты — теперь все сообщения от компаний '
#                                  'собраны в отдельной папке.\n'
#                                  '\n'
#                                  'В неё поступают уведомления от компаний, '
#                                  'которым пользователь разрешил отправку '
#                                  'сообщений по номеру телефона, а также '
#                                  'сообщения от бизнес-сообществ.\n'
#                                  '\n'
#                                  'Обновление доступно в приложениях ВКонтакте '
#                                  'и VK Мессенджер на всех платформах, а также '
#                                  'в новом интерфейсе мессенджера в веб-версии '
#                                  'ВКонтакте.',
#                          'type': 'post',
#                          'views': {'count': 207760}},
#                         {'attachments': [{'photo': {'access_key': '0acf8676018284242e',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353619,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '09e65e10a46810b193'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '226a1b018fe54c2dae',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353620,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-1.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '20ab6edc8dd7ca3ea6'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '36345a4ceb9271b0c4',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353621,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
# ...
#                                           'type': 'photo'}],
#                          'comments': {'count': 570},
#                          'date': 1705658403,
#                          'from_id': -22822305,
#                          'hash': 'bi0TNz0XKibngW1vzQ',
#                          'id': 1455138,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 3589,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 587},
#                          'text': 'Будьте внимательнее, когда скидываете не те '
#                                  'сообщения в не те чаты!',
#                          'type': 'post',
#                          'views': {'count': 1202415}},
#                         {'attachments': [],
#                          'comments': {'count': 873},
#                          'date': 1705481335,
#                          'from_id': -22822305,
#                          'hash': '2w_GjQPzA8NPadyhCw',
#                          'id': 1454278,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 874,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 201},
#                          'text': 'Какие две аудиозаписи лучше всего описывают '
#                                  'ваш профиль ВКонтакте?\n'
#                                  '\n'
#                                  'Ответы в виде треков принимаем в '
#                                  'комментариях 👇',
#                          'type': 'post',
#                          'views': {'count': 964410}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd51776f9e40e070544',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 391,
#                                                     'date': 1705160174,
#                                                     'description': '',
#                                                     'duration': 63,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242525,
#                                                     'local_views': 1704960,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_56351e67HKFCEoxK6YDXqh1yG8QJ1tRgwqCLgw3D4hKkPv5GsHItgFwQiy3qhtGpHhUY8T_k4FL3kr6MeqKOfqQv03SCSh-yb99BjSRNG2XX0i4',
#                                                     'views': 1704960,
#                                                     'width': 1080}}],
#                          'comments': {'count': 389},
#                          'date': 1705161602,
#                          'from_id': -22822305,
#                          'hash': 'zHC60fQ3puc9u5vc1Q',
#                          'id': 1453687,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1658,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 208},
#                          'text': 'На дворе старый Новый год — отличный повод, '
#                                  'чтобы послушать новогодние поздравления от '
#                                  'пользователей ВКонтакте, нашей команды и '
#                                  'звёзд.\n'
#                                  '\n'
#                                  'Всех с Новым годом ещё раз!',
#                          'type': 'post',
#                          'views': {'count': 2352755}},
#                         {'attachments': [{'photo': {'access_key': 'a3b887c4e40ac6597c',
#                                                     'album_id': -7,
#                                                     'date': 1705066102,
#                                                     'id': 457346145,
#                                                     'orig_photo': {'height': 1500,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu',
#                                                                    'width': 1500},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1500x1500',
#                                                                'width': 1500},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun21-2.userapi.com/s/v1/ig2/2HlEWsMrYZETBygPyHJ3Zl_TIg7831yePRsCjsrvkQzn3M3y36_r9Ieaa7G8e0dhDy6SKbXqqKDROK2nPaBY-GAs.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'ff926457a296b2f6a6'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 198},
#                          'date': 1705064403,
#                          'edited': 1705066102,
#                          'from_id': -22822305,
#                          'hash': 'St7bnPht7vTxKxAneQ',
#                          'id': 1453453,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 883,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 189},
#                          'text': 'Как прошли ваши новогодние праздники? Хотя '
#                                  'погодите, сейчас мы угадаем!\n'
#                                  '\n'
#                                  '• Вы много общались и по сравнению с '
#                                  'предновогодней неделей отправили на 39% '
#                                  'больше сообщений.\n'
#                                  '\n'
#                                  '• Дарили друг другу много подарков. Среди '
#                                  'самых популярных — зелёный дракон, ангел и '
#                                  'новогодний стеклянный шар.\n'
#                                  '\n'
#                                  '• О, а ещё провели на 50% больше тренировок, '
#                                  'чем годом ранее! Кстати, кто-то из вас начал '
#                                  'тренироваться сразу после боя курантов — в '
#                                  '00:02.\n'
#                                  '\n'
#                                  'Ладно, признаёмся, мы не угадывали, а '
#                                  'посмотрели статистику. Вы тоже посмотрите, '
#                                  'там много любопытного: '
#                                  'vk.com/press/newyear-users-2024.',
#                          'type': 'post',
#                          'views': {'count': 551495}}]}}

# %%
len(response.json()['response']['items'])
## 100
# Out:
# 100

# %%
response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'count': 488},
#  'marked_as_ads': 0,
#  'hash': 'bVCss2zuaafY0yg5jQ',
#  'type': 'post',
#  'push_subscription': {'is_subscribed': False},
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1732001942,
#     'id': 457354304,
#     'owner_id': -22822305,
#     'access_key': 'c63f20a62cafbe0d28',
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604'},
#      {'height': 807,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807'},
#      {'height': 1080,
#       'type': 'z',
#       'width': 1080,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'd5949a55bce1800b31',
#     'orig_photo': {'height': 1080,
#      'type': 'base',
#      'url': 'https://sun21-1.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#      'width': 1080}}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1732001942,
#     'id': 457354305,
#     'owner_id': -22822305,
#     'access_key': '6a9bd0496456580f64',
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604'},
#      {'height': 807,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807'},
#      {'height': 1080,
#       'type': 'z',
#       'width': 1080,
#       'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'bc07575040c6ce65c7',
#     'orig_photo': {'height': 1080,
#      'type': 'base',
#      'url': 'https://sun21-1.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#      'width': 1080}}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1732001942,
#     'id': 457354306,
#     'owner_id': -22822305,
#     'access_key': 'b8529cc9a2bd86655a',
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604'},
#      {'height': 807,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807'},
#      {'height': 1080,
#       'type': 'z',
#       'width': 1080,
#       'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': '10c4de8e50fca74f07',
#     'orig_photo': {'height': 1080,
#      'type': 'base',
#      'url': 'https://sun21-2.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#      'width': 1080}}}],
#  'date': 1732002300,
#  'from_id': -22822305,
#  'id': 1526639,
#  'likes': {'can_like': 0, 'count': 222, 'user_likes': 0},
#  'owner_id': -22822305,
#  'post_type': 'post',
#  'reposts': {'count': 44},
#  'text': 'Мы изучили портрет пользователя донатных сервисов и узнали много интересного.\n\nОказалось, что молодёжь чаще поддерживает художников и иллюстраторов, а люди старше 25 лет больше донатят за образовательный контент.\n\nЧто мотивирует людей донатить? У мужчин на первом месте желание поддержать автора, а женщины больше ценят доступ к эксклюзивным материалам.\n\nЛистайте карточки, там ещё больше интересных фактов! А поддержать своих любимых авторов вы можете через [vk.com/vkdonut|VK Donut].',
#  'views': {'count': 110475}}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.

# %% [markdown]
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'VK Музыка обновилась! Что ново': [488, 791, 228, 1728310195],
#  'В чатах ВКонтакте появилась па': [1464, 425, 131, 1731411000],
#  'Какие персонажи — такие и их л': [595, 1228, 198, 1726227240],
#  'Мы изучили портрет пользовател': [488, 222, 44, 1732002300],
#  'Новая программа монетизации от': [822, 1004, 343, 1727083149],
#  'Обновился VK Мессенджер в веб-': [480, 814, 329, 1726748100],
#  'Представляем VK AdBlogger — но': [162, 457, 175, 1726654200],
#  'Сегодня ВКонтакте исполнилось ': [628, 1745, 259, 1728560919],
#  'Спешим поделиться крайне милым': [2261, 3407, 655, 1730375700],
#  'Что можно успеть за 60 секунд?': [433, 1754, 186, 1726757657]}

# %% [markdown]
# ### Скрипты

# %%
import schedule # Импортируем модуль schedule
def task(): 
    print('Hello! I am a task!') 
    return

# %% [markdown]
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле schedule используется метод every(), который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.
#
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:

# %%
schedule.every(1).minutes.do(task)
# Out:
# Every 1 minute do task() (last run: [never], next run: 2024-11-20 12:30:39)

# %% [markdown]
# Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:
# ``` schedule.every(1).hour.do(task) ```

# %%
import schedule
import time 

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(1).minutes.do(task)

while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Hello! I am a task!
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 12
#      10 while True:
#      11     schedule.run_pending()
# ---> 12     time.sleep(1)
#
# KeyboardInterrupt:
